# %%
# !python --version

# %%
# !pip install -q -U pip
# !pip install -q numpy
# !pip install -q pandas
# !pip install -q ckiptagger
# !pip install -q tqdm
# !pip install -q tensorflow==1.14.0
# !pip install -q ipywidgets

# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                            title
# 0         0    體育         亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育        9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育             如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育            超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育          騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# ...     ...   ...                              ...
# 1795   1795    遊戲  LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲            穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲          騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                   LOL你不知道的黑科技打法！
# 1799   1799    遊戲                 遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
ws = WS('../data/')
pos = POS('../data/')

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    word_s = ws([title])
    word_p = pos(word_s)

    # END YOUR CODE
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    word_s = ws([title])
    word_p = pos(word_s)

    # END YOUR CODE
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
ind = 0
for sent in train_title_cuts.values():
    for word,_ in sent:
        if word not in word2index:
            word2index[word]=ind
            index2word[ind]=word
            ind+=1   

# END YOUR CODE

# %%
word2index['溫暖']
# Out:
# 1520

# %%
index2word[1520]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index):
    vector = np.zeros(len(word2index))
    for ind in [word2index[w] for w,i in pairs]:
        vector[ind]+=1

    # END YOUR CODE
    return vector

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['王者榮耀', '曼聯', '蓋倫', '騰訊王', '黃希揚', '德比', '白起', '馬內', '埃姆雷', '中金', '堯治河', '泰倫盧成', '北京人和', '余小C', '盼保', '埃梅里', '馬里奧', '羅森', '周琦', '尤納斯', '韓長賦', '艷武漢', '伊亞', '科斯塔', '馬雲', '璞麗', '上港', '梅西納', '帕克成', '侯森', '奧尼爾', '杜蘭特', '奧運', '星巴克', '中超', '秦緒文', '韋神', '興業', '嘉年華', '峽谷里', '景泰石', '詹', '聯盟里', '泰倫', '梅西', '富德', '本澤馬', '大豐', '意大利杯', '綠心', '郭春林', '賞月夜', '索尼', '小智', '賈躍亭', '安利', '藍星', '斯威', '斯諾克', '夢琪', '馬卡報', '李謹詺', '張藝謀', '恆生', '斐濟', '衛報', '微星', '微醫', '阿木木歷', '泰倫盧', '裴擒虎', '拳皇', '詹姆斯', '王者榮', '武磊', '鎧單', '馬競', '唐培科', '阿珂', '綠軍', '姆巴佩', '男乒', '紫鑫', '羅', '魯能', '拜仁', '格力', '李暉', '克洛普', '林斌', '郭懿', '英特爾', '溫氏', '魅族', '洛瑞', '劉熾平', '皮爾洛', '埃米爾岡', '大聶', '聯發科']
# =======================
# VC : ['營銷', '破', '養', '進口', '分漲', '打理', '炒', '對付', '投', '底背離', '添脫', '行', '輔助', '實拍', '宣一', '撐', '審查', '覲見', '要', '徵召', '提升到', '奪', '虐爆', '打磨', '揭密', '曝', '拋棄', '超越', '秒選', '刪除', '投放', '投身', '錄制', '炸', '飲', '考察', '保駕', '領', '派出', '吸收', '逗', '豪取', '體驗', '游里結', '拋售', '刷到', '訓練', '取代', '購', '招待', '移', '待', '開啓', '加', '照看', '防控', '刷新', '割', '換', '迎接', '購買', '進出口', '唱起', '開好', '學到', '發', '翻譯', '禁', '看待', '瞧瞧', '炒作', '改造', '改變', '包裝', '等到', '嘗嘗', '騎', '招聘', '誤判', '教', '擔', '建', '冠絕', '戰勝', '結', '殺', '撒', '銷售', '打贏', '拋投', '收穫', '研發', '承受', '誘', '破棄', '看', '開', '攻', '採用', '春栽']
# =======================
# Na : ['營銷', '語言', '女團', '支票本', '樣', '命運', '利潤', '豬', '飼料', '圖文', '保質', '凱爾特人', '流量', '心骨', '濾鏡', '絕招', '老師', '宜興人', '金幣', '野心', '雙叒叕', '季節性', '新妖', '親子', '鴨脖', '總決賽', '美股', '綠道', '水友', '峰', '重磅', '天命杯', '紀錄', '勝率', '花崗岩', '金華人', '囧態', '爆料王者', '秘密', '聯', '醫保', '招人煩', '現金', '路人', '精神', '支柱', '金子', '時光', '田園', '麒麟', '方面', '風景', '士官', '黃金', '耗電量', '最為難', '青訓', '靜電', '珍藏版', '主帥', '頭銜', '茅台酒', '農家樂', '油菜', '優勢', '渲染器', '破血', '婦女', '證金', '薰衣草', '蠱', '兄弟', '外形', '大咖', '老鼠', '天命', '姑娘', '知識', '滄桑', '小兵', '國乒女隊', '狀態', '布陣', '戰績', '荒坡', '收穫', '上幣', '渣男', '盛贊', '高家路', '表格', '溫商', '妻', '鳳梨', '大會', '文', '集團', '神裝', '老農', '電影']
# =======================
# COLONCATEGORY : [':', '：']
# =======================
# Nc : ['平橋鄉', '實體店', 'WKG&M-1世界', '京東', '開面店', '縣里', '神壇', '月亮灣', '兩岸', '中科院', '川藏線', '壽寧', '岳陽市', '寧夏', '火車站', '九寨溝', '冠格局', '洗車店', '小鎮', '華僑城', '阜南縣', '金州', '工信部', '延津', '小丘鎮', '手游', '陽朔', '荒野', '塞班', '去處', '宿城', '國外', '五一', '聊城', '滑縣', '泰安', '母公司', '省', '茨城', '古城', '地獄', '產茶縣', '超大陸', '古鎮', '吉爾吉斯斯坦', '體育場', '興鄉村', '巴釐島', '博鰲', '西藏', '轄區', '背後', '南寧', '農資店', '原地', '平邑', '拉薩', '安居區', '球場', '尼山', '高空', '江夏鎮', '大馬', '冰城', '以色列', '哈尼梯田', '萊加內斯', '酉莊', '果園地', '加州', '科', '雷區', '奧蘭多', '主題店', '西安比', '工行', '風景區', '現場', '普吉島', '夏威夷', '瑞典', '超京', '下轄縣', '華鎣', '南陽', '嵐皋', '香格里拉', '盧氏縣', '城市', '火鍋店', '宅', '茂陵', '寶閣', '紅河谷', '後台', '北大', '漁場', '評論區', '窮游', '皖南']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['應對', '罰款', '開戰', '效力', '再見', '拍照', '加持', '計算出來', '融資', '上架', '解密', '復仇', '入賬', '護航', '收回來', '解惑', '解體', '通話', '定位', '領銜', '罵屌絲', '導航', '一網打盡', '退貨', '扣分', '分段', '相比', '加起來', '提前', '代打', '加油', '助威', '站台', '退款', '充飢', '退改', '分紅', '執教', '加工', '充氣', '鋪平', '加冕', '抓來', '分組', '騙錢', '鍍金', '解圍']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['白', '應該', '好像', '竟然', '並', '隨', '大力', '又', '剛', '這麼', '可', '依舊', '攜手', '年年', '要', '在', '簡直', '一手', '玩絕', '總', '即', '屢', '真是', '均', '已然', '先', '再次', '多多少少', '一直', '直', '不可', '大幅', '重新', '全力', '甚至', '偶爾', '有沒有', '同', '專職', '少', '為什麼', '首', '只得', '全程', '未', '永', '急劇', '可能', '更', '或許', '原來', '非', '快', '至今', '居然', '盡快', '大概', '差點', '相互', '再度', '相', '仍然', '能夠', '絕對', '完全', '不得不', '還', '搞不好', '立即', '只有', '絕', '真', '天南地北', '總算', '沒想到', '可否', '不應該', '頻', '隨地', '還可以', '不會', '隆', '始', '一起', '為啥', '迫不及待', '如何', '將', '率先', '私', '怎樣', '經常', '互相', '預先', '新', '會', '連續', '呼好', '沒', '哈哈']
# =======================
# P : ['趁著', '隨', '向', '待', '如', '隨了', '根據', '與', '自', '將', '在', '臨', '直至', '跟', '比', '趁', '為', '幫', '和', '對', '等', '遭', '憑', '針對', '靠', '繼', '被', '因', '到', '當', '受', '除了', '距離', '往', '就', '自從', '為了', '給', '從', '以', '除', '按', '至', '把', '離', '於', '關於', '用', '慘遭', '比如', '像']
# =======================
# VG : ['屬於', '稱得上', '賣成', '如', '稱', '誤認成', '酷似', '建成', '理解為', '當上', '改造成', '升任', '並列', '變成', '排', '做成', '譽為', '等於', '形成', '姓', '封號', '居', '成為', '為', '戰成', '充當', '叫做', '竟是', '堪稱', '評選', '美成', '類似', '猶如', '當', '算是', '屈居', '似', '排行', '非', '排名', '變', '做', '算', '應聘', '叫', '稱為', '像', '投票成', '作為', '名叫', '集成', '疑似', '當成', '彷彿', '化', '合成', '稱作', '成', '當作']
# =======================
# Neu : ['第114', '二〇三', 'b120', '9-0', '3.5', '三十', '3:1', '24', '0', '2:3', '萬億', '兩萬', '24億', '135', '30', '0:3', '70萬', '1300萬', '50多', '400萬', '1.1.2', '1', '3100', '二', '千千萬', '！2018', '一萬', '47', '56', '十五萬', '9-1', '32', '37', '300萬', '120', '10', '318', '十三', '一千', '60萬', '第一！', '30000億', '6.9', '1299', '40', '20億', '第3', '5.7', '2.37億', '第三', '47億', '50', '12', '2018.', '5000', '第七', '零', '10010', '7億', '七', '五一', '711', '15', '20萬一', '1099', '2400', '600', '22', '25', '4000', '七八千', '十億', '42', '五', '1.3萬', '4.5億', '38', '甲', '數千萬', '730萬', '2018.5.6', '100', '2萬', '2018-05-06 ', '2000', '0-', '2018', '2:1', '2', '175', '千億', '1.8億', '3-1', '4.7億', '6800', '120萬', '60多', '兩', '1-2', '00']
# =======================
# Nf : ['晚', '塊', '樣', '公里', '隻', '行', '道', '篇', '步', '位', '些', '台', '頓', '株', '股', '噸', '天', '輪', '類', '分', '分鐘', '號', '色', '戶', '輛', 'K', '口', '英吋', '日', '只', '碗', '項', '座', '鍋', '斤', '頭', '棵', '部', '路', '周', '屆', '槍', '張', '所', '則', '米', '片', '點', '節', '盤', '胎', '件', '歲', '本', '期', '畝', '級', '門', '袋', '批', '群', '元', '對', '筆', '名', '招', '掛', '頁', '週', '隊', '場', '度', '港元', '方', '把', '種', '班', '套', '支', '家', '年', '串', '條', '遍', '次', '毛', '刻', '層', '局', '處', '美元', '款', '關', '個', '番', '秒', '檔', '句', '回', '票']
# =======================
# VJ : ['負於', '入選', '同情', '緊缺', '偏愛', '從事', '納入', '沈迷', '羨慕', '共享', '擁有', '分享', '平', '持有', '替代', '大勝', '出身', '身臨', '充', '贏下', '發生', '不到', '受到', '限', '曬', '贊同', '煥發', '減持', '錯過', '遺傳', '認', '翻倍', '逾', '抗', '佔', '僅次於', '忘懷', '缺少', '嫌棄', '領先', '沒', '熱心', '吸引', '錯失', '領跑', '脫', '欣賞', '缺', '超', '獲', '虧損', '冷落', '處於', '爆發', '看不過去', '喪失', '達到', '看好', '適用', '獨佔', '吃上', '得', '領略', '順應', '維持', '遭遇', '懷念', '連接', '超過', '養有', '入圍', '輸掉', '近', '惜', '展望', '為', '高達', '贏得', '出', '看懂', '震撼到', '毫無', '歸', '歸屬於', '含有', '適應', '忽視', '過完', '僅次', '曝限', '失', '蘊藏', '失去', '恭喜', '減', '忽略', '新增', '不敵', '賽', '出於']
# =======================
# VD : ['賣', '送', '寄予', '售', '分', '禁售', '轉讓', '傳', '支付', '補繳', '輸', '贏', '輸給', '郵給', '發', '交付', '發給', '貸款', '搶', '欠', '予', '坑', '速遞', '白送', '借', '配', '清繳', '補貼', '付', '借貸', '發放', '給', '提供', '給予', '貸', '拒賠', '收費', '供應', '還']
# =======================
# Dfa : ['非常', '多', '過於', '好', '這麼', '極', '更為', '有點', '比較', '超', '遠遠', '較', '同樣', '過', '十分', '如此', '太', '頗', '更', '還', '不大', '越來越', '最', '有些', '很', '遠', '還要']
# =======================
# VH : ['白', '惡化', '老', '主動', '行', '很多', '看呆', '偽風口', '出世', '有意思', '稱霸絕', '開大', '狂野', '上去', '低調', '得寸進尺', '恍然大悟', '適合', '豐收', '力輓狂瀾', '犀利', '炫酷', '泛濫成災', '開花', '簡約', '冒雨', '恐怖', '密集', '莫名其妙', '大跌', '親切', '跌，', '別具一格', '富', '色綠', '變幻莫測', '堅', '輸球', '舊', '頂尖', '百出', '心酸', '長', '美麗', '哭笑不得', '年輕', '面世', '開啓', '理智', '傳統', '還可以', '連敗', '著急', '無緣', '合格', '如何', '難', '連續', '開通', '掉', '傻', '靦腆', '主觀', '熟', '發愁', '待機', '單身', '缺席', '生存', '斜', '高度', '乾嘛', '通車', '笨', '重大', '獨立', '強悍', '悲觀', '充足', '涼爽', '低', '不可思議', '截止', '慎', '爆表', '曝光', '怎麼', '不行', '近', '迷你', '專業', '公平', '竊喜', '火爆', '密', '高', '智障', '佳', '轟動', '相反']
# =======================
# Cbb : ['不僅', '可是', '只有', '並', '不過', '還不如', '另外', '即使', '只要', '要是', '因為', '並且', '雖然', '否則', '但是', '縱使', '而是', '既', '如果', '但', '跟著', '因', '若', '反而', '不管', '假如', '連', '就算', '不如', '既然', '而', '不然']
# =======================
# Nd : ['旅遊節', '2035年', '永久', '15日', '春天', '當時', '夏窗', '夏季', '週末', '6日', '四月', '一會', '後來', '半夜', '三國', '季度', '2017年', '最近', '春季', '短期', '熱天', '05月', '花季', '一大早', '大中', '多久', '5日', '季', '90年', '現代', '13點', '正月', '當年', '23日', '19年', '3月', '臨時', '2020年', '不久', '春', '現在', '12日', '狗年', '如今', '後', '一日', '10點', '-5', '過去', '2019年', '雍正', '米節', '2018', '6月', '今天', '目前', '小時候', '寒武紀', '採摘節', '今年', '隔年', '2005年', '文化節', '相親節', '旺季', '4日', '以前', '8月', '周', '首日', '夏日', '五月', '晚清', '夏天', '近日', '6旬', '00年', '昨天', '立夏', '夜', '7日', '一下', '明晚', '以後', '下旬', '5月', '那時', '週二', '夏', '同時', '1日', '30號', '長期', '後期', '中期', '7號', '4月', '初夏', '九月', '晚上']
# =======================
# VA : ['換人', '換股', '充值', '開盤', '收尾', '行', '下場', '打顫', '出欄', '避暑', '投訴', '入院', '餵尿素', '醒', '賺錢', '扶牆', '收錢', '下海', '下雪', '上升', '輪換', '問世', '盤旋', '進貨', '連冠', '讀書', '伸手', '加價', '會師', '開啓', '字字珠璣', '出擊', '下卡', '報檢', '蹲坑', '擺地攤', '吸粉', '抽卡', '聊天', '實習', '變盤', '怒吼', '復盤', '變身', '通關', '戴罪', '爭吵', '放水', '誕生', '共贏', '脫貧', '搭檔', '坐', '刮風', '奪冠', '掙扎', '上線', '回家', '就業', '立刷', '偷腥', '出國', '開播', '說話', '喧囂', '上場', '徵信', '代工', '建功', '出行', '爭霸', '產仔', '鬥米', '倒計', '創業', '保量', '見面', '追肥', '成交', '上雙', '探險', '砸盤', '結婚', '求生', '打團', '工作', '看盤', '絕殺', '卡', '開業', '報警', '捲土重來', '炒房', '刷單', '報關', '反彈', '追債', '合伙', '出來', '上班']
# =======================
# COMMACATEGORY : [',', '，']
# =======================
# Nes : ['近', '同', '前', '何', '該', '上', '頭', '後', '某', '首', '另', '各', '貴', '下', '每', '本']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# EXCLAMATIONCATEGORY : ['!', '！']
# =======================
# Di : ['起來', '著', '過', '個', '了']
# =======================
# Nep : ['啥', '此', '那', '其中', '什麼', '其', '哪', '這']
# =======================
# Caa : ['及', '或是', '或', 'VS', '或者', '跟', '比', '至', '又', '還是', '到', '與', '和', '暨']
# =======================
# VCL : ['用於', '栽進', '赴', '蒞臨', '入', '玩遍', '出發到', '重返', '穿透', '退出', '走進', '度過', '跌至', '上', '走到', '來到', '在', '前來', '重回', '回到', '跌出', '進', '走過', '升至', '存進', '直達', '住', '穿越', '過', '出', '留在', '去', '到', '進入', '暗渡', '穿過', '到達', '盤踞', '路過', '往', '橫掃', '遠離', '走下', '遊覽', '走訪', '登陸', '深入', '抵達', '前往', '回', '回歸']
# =======================
# Neqa : ['12%', '20%', '10%', '大多數', '多', '四成', '不少', '80%', '百分之八十', '一半', '句句', '這麼多', '15%', '很多', '41.8%', '100%', '遍', '一些', '其他', '67%', '90%', '6%', '一點', '更多', '8%', '多少', '步步', '三分之一', '一處處', '許多', '無數', '多點', '任何', '大量', '哪些', '1/4', '1%', '30%', '一切', '其它', '半', '那些', '全', '個個', '大多', '這些', '有的', '部分', '有些', '9.89%', '所有', '0.8%', '滴滴']
# =======================
# Nh : ['各自', '本人', '對方', '她', '大家', '屌絲', '他們', '父子倆', '它', '我', '她們', '雙方', '自己', '它們', '小眾', '他', '你', '您', '俺們', '一方', '我們', '私人', '自我', '人家', '別人', '個人', '自身', '誰', '各位', '你們']
# =======================
# FW : ['B', 'SKU', 'l ', 'J', 'DNF：', 'Guru', '9A91', 'SIo', 'dnf', 'DASH', 'PK', '丨', 'KBM', 'AWM', 'Soloking', 'Pro', 'BTC', ' CCR', 'GoogleI/O2018', 'HTC', 'qq', 'FF ', 'max2', 'cba', 'wifi', 'G', 'X', 'lck', ' vs 利物浦', 'Focus', 'MSCI', 'Alan', 'eStar', 'ios', 'PGM 0-1 SUP', 'OB', 'vip', 'Kakao', 'PPP', '8d', 'Day', '+', 'e', 'GPP', 'Q', 'AIC', ' 展', '~', 'Credo', 'Cotswolds', 'OTT', ' 利', ' MDL', 'CBA', 'TT', 'LOL：', '+4', '>', 'DNF ', 'W', 'h', 'OV', 'numb', 'i7', 'PS', 'VR ', 'D', 'ban', 'kpl', 'King James', 'DNF', 'QDC', 'IG', 'Lol里', 'iPad', 'PVE', 'BAT', 'adc', 'AP', 'C', 'QQ', ' 比', 'SSG', 'LOL：MSI', 'eStarPro vs WF.D', 'SUP', 'K', 'mix2', 'steam', 'QG', 'KPL', 'Oeanc', 'Mc', ' 28', '2', 'LSPL', 'pro7', 'N+1', '│', '：AG']
# =======================
# SHI : ['是', '像是']
# =======================
# VE : ['准', '想', '樂見', '想起', '發佈', '討說', '深思', '講解', '知詢', '要', '避免', '看出', '賭約', '預防', '自嘲', '說明', '聯想', '考慮', '披露', '見到', '見證', '禁止', '猜', '提醒', '算', '公告', '示範', '發誓', '介紹', '提起', '估值', '探討', '看看', '識別', '聊', '安排', '訴說', '談', '廣播', '宣佈', '設想', '調研', '回顧', '講', '預告', '聽到', '預期', '看到', '鑒定', '暗示', '管', '認為', '判定', '聽', '傳聞', '做到', '允許', '公示', '限制', '證', '查看', '稱', '防止', '回答', '確認', '盛贊', '問', '研究', '呼籲', '發現', '揭曉', '證明', '假設', '見', '判斷', '探索', '警惕', '炫耀', '提猜', '爆料', '預計', '查', '想好', '查找', '感嘆', '承諾', '精准', '呼', '幻想', '商量', '形容', '告訴', '預測', '公認', '聽說', '檢測', '以為', '反對', '申卡', '報道']
# =======================
# DE : ['的', '地', '得', '之']
# =======================
# VHC : ['機構化', '熱', '破', '麻煩', '產生', '團結', '感動', '繁榮', '恢復', '增強', '結束', '增 ', '冷卻', '國際化', '加快', '平衡', '開', '普及', '公開', '告破', '暫停', '停', '降低', '增加', '縮小', '穩定', '陷', '現代化', '肥', '豐富', '規模化', '擴張', '優化', '愁壞', '震驚', '強化', '變動', '智能化', '減少', '滿足', '煩', '辛苦', '溫暖', '壞', '淡化', '可憐', '下來', '傷', '斷', '凍', '還原', '愁死', '增長']
# =======================
# Ng : ['起', '之外', '以來', '時', '下', '般', '間', '上', '以後', '中', '後', '之間', '之後', '底', '之中', '之上', '而言', '以上', '之內', '前', '來', '以下', '為止', '之下', '以外', '裡', '內', '外', '之前', '初', '左右']
# =======================
# VK : ['擔心', '恐', '忘記', '指望', '懂', '抱歉', '願', '不滿', '顯示', '放心', '肯定', '討厭', '瞭解', '有利於', '明白', '怕', '堅持', '願意', '害怕', '同意', '想見', '欲', '回憶', '確定', '知道', '忘', '恨', '覺', '覺得', '小心', '感受', '奇怪', '懂得', '知', '曲解', '意想不到', '流傳', '不忘', '依賴', '所謂', '需要', '意外', '感謝', '面臨', '感覺', '注意', '懷疑', '喜歡', '期待', '介意', '信', '意味', '希望', '遺憾', '盼', '理解', '需', '遇', '感覺到']
# =======================
# Ncd : ['上方', '畔', '對面', '前沿', '下', '東', '旁邊', '那裡', '間', '末端', '上', '中間', '中', '東方', '裡面', '東西部', '哪', '兩旁', '中部', '外面', '這裡', '東部', '哪兒', '那邊', '邊', '底部', '以下', '方', '哪下', '內', '裡', '哪裡', '一帶', '西部', '西', '外', '上面', '北', '當中']
# =======================
# A : ['彩色', '乒乓', '真正', '野生', '常務', '碧藍', '必備', '同一', '麻辣', '單', '二手', '現行', '優質', '中西', '火紅', '中', '雙', '獨角', '國產', '總', '上上', '共同', '超級', '獨家', '基礎', '新一代', '新興', '現役', '基層', '超', '主', '同等', '獨門', '長途', '最佳', '寶有', '後置', '地下', '高度', '唯一', '非', '前置', '業餘', '綜合', '重磅', '歐式', '多餘', '一般', '頭號', '大幅度', '眾', '額外', '小本', '原']
# =======================
# V_2 : ['有']
# =======================
# VL : ['肯', '導致', '愛好', '讓', '後悔', '致', '用來', '能', '喜好', '甘願', '愛', '不惜', '開始', '令', '使得', '持續', '習慣', '使', '故意', '便利', '趨於', '敢']
# =======================
# T : ['嗎', '啦', '來', '麼', '吧', '呢', '嘛', '咯', '矣', '了', '去', '哦', '哪', '的', '啊']
# =======================
# VI : ['專用', '著稱', '驚艷', '傾心', '取勝']
# =======================
# DASHCATEGORY : ['—', '-']
# =======================
# I : ['瑪法里奧', '哦']
# =======================
# Dk : ['結果', '據說', '外傳', '想不到', '據聞', '那', '反過來', '那麼']
# =======================
# VF : ['請', '率領', '停止', '圖', '試', '準備', '催', '推選', '帶領', '勸說', '助', '止住', '申請', '勸住', '試試', '策劃', '拒絕', '要求', '拒', '繼續', '邀', '打算', '逼', '擬', '判', '鼓勵', '叫', '告誡']
# =======================
# Da : ['才', '將近', '近', '唯獨', '足足', '只', '最多', '僅', '幾乎', '不下', '幾近', '正好', '約', '共', '光']
# =======================
# PARENTHESISCATEGORY : ['「', '》', '」', '(', '《', '（', '）']
# =======================
# Nv : ['營銷', '銷售', '回歸', '買單', '登山', '問', '抗戰', '輔助', '燃燒', '度假', '供電', '研究', '惡搞', '經歷', '崩潰', '航海', '射擊', '創業', '翻譯', '疊加', '旅遊', '管理', '批發', '灌籃', '錄制', '關聯', '開發', '判罰', '生產', '推薦', '代理', '護髮', '訴訟', '防治', '解救', '兼職', '組合', '遊樂', '增發', '體驗', '思考', '分銷', '配置', '工作', '絕殺', '私募']
# =======================
# PERIODCATEGORY : ['。', '·']
# =======================
# VAC : ['推進', '蒸發', '上演', '集合', '動', '移動']
# =======================
# Dfb : ['極了', '些', '一點']
# =======================
# Cab : ['等', '等等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['多', '半', '以上', '幾']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 'ETCCATEGORY', 'EXCLAMATIONCATEGORY',
        'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY', 'SEMICOLONCATEGORY', 
        'SPCHANGECATEGORY', 'WHITESPACE', 'Cab', 'Cba','DE'

        # END YOUR CODE
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
def cosine_similarity(bow1, bow2):
    similarity=np.dot(bow1,bow2)/(np.linalg.norm(bow1, ord=2)*np.linalg.norm(bow2, ord=2))

    # END YOUR CODE
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'體育': array([0.04      , 0.01333333, 0.00333333, ..., 0.        , 0.        ,
#         0.        ]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 70, '遊戲': 10, '財經': 8, '農業': 6, '旅遊': 5, '科技': 2})
# predict 財經 :  Counter({'財經': 66, '科技': 21, '旅遊': 12, '農業': 12, '體育': 7, '遊戲': 5})
# predict 科技 :  Counter({'科技': 61, '財經': 14, '農業': 13, '體育': 10, '旅遊': 9, '遊戲': 6})
# predict 旅遊 :  Counter({'旅遊': 57, '農業': 6, '財經': 4, '遊戲': 2, '體育': 1, '科技': 1})
# predict 農業 :  Counter({'農業': 58, '科技': 5, '旅遊': 5, '遊戲': 3, '體育': 2, '財經': 2})
# predict 遊戲 :  Counter({'遊戲': 74, '旅遊': 11, '體育': 9, '科技': 9, '財經': 6, '農業': 4})
